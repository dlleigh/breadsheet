# %% [markdown]
# ## Whole Wheat Sourdough

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import PrefermentCalculator, create_formula, format_and_display

# %%
calc = PrefermentCalculator(
    num_loaves=4, 
    weight_pounds=1,
    weight_ounces=12,
    waste_factor=0.02
)
calc.print_batch_info()
# Out:
# 4 loaves at 754-833 grams
# total weight: 3,238.65 grams

# %%
pre_fermented_flour_ratio = 0.20
title='Whole Wheat Sourdough'

formula = create_formula({
    "whole-wheat-flour": 100,
    "desem": 40,
    "water": 91,
    "malt": 1,
    "salt": 2.48
})

steps='''
- Autolyse 15 min
- Bulk fermentation: 3 hr (fold every 15 min for first 90 min)
- shape
- Proof: 90 min'''

final_dough = calc.calculate_straight_dough(formula)
format_and_display(final_dough, calc, title=title, steps=steps)
# Out:
# Whole Wheat Sourdough
#
#
# - Autolyse 15 min
# - Bulk fermentation: 3 hr (fold every 15 min for first 90 min)
# - shape
# - Proof: 90 min
#
# 4 loaves at 754-833 grams
# overall formula total = 234.5%
#
# |                   |   baker% |    grams |    oz |
# |:------------------|---------:|---------:|------:|
# | whole-wheat-flour |   100.00 | 1,381.00 | 48.70 |
# | desem             |    40.00 |   552.00 | 19.50 |
# | water             |    91.00 | 1,257.00 | 44.30 |
# | malt              |     1.00 |    13.80 |  0.49 |
# | salt              |     2.48 |    34.30 |  1.21 |
