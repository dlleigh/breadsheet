# %% [markdown]
# ## Whole Wheat Sourdough

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import RecipeCalculator, create_formula, format_and_display

# %%
calc = RecipeCalculator(
    num_loaves=8, 
    weight_pounds=1,
    weight_ounces=12,
    waste_factor=0.02
)
calc.print_batch_info()

# %%
pre_fermented_flour_ratio = 0.20
title='Whole Wheat Sourdough'

formula = create_formula({
    "whole-wheat-flour": 100,
    "water": 85,
    "malt": 0.8,
    "salt": 2
})

desem = create_formula({
    "whole-wheat-flour": 100,
    "water": 60,
    "desem": 10
})

steps='''
- Autolyse 15 min
- Bulk fermentation: 3 hr (fold every 15 min for first 90 min)
- shape
- Proof: 90 min'''

desem, final_dough = calc.calculate(formula, desem_df=desem, pre_fermented_flour_ratio=pre_fermented_flour_ratio)
format_and_display(formula=final_dough, desem=desem, calc=calc, title=title, steps=steps, reserved_seed_grams=75)
# Out:
# Whole Wheat Sourdough
#
#
# - Autolyse 15 min
# - Bulk fermentation: 3 hr (fold every 15 min for first 90 min)
# - shape
# - Proof: 90 min
#
# 8 loaves at 754-833 grams
# overall formula total = 189.8%
#
# Overall Formula:
#
# |                   |   baker% |    grams |     oz |
# |:------------------|---------:|---------:|-------:|
# | whole-wheat-flour |   100.00 | 3,449.00 | 122.00 |
# | desem             |     2.00 |    69.00 |   2.43 |
# | malt              |     0.80 |    27.60 |   0.97 |
# | salt              |     2.00 |    69.00 |   2.43 |
# | water             |    85.00 | 2,932.00 | 103.00 |
#
# Desem:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | whole-wheat-flour |   100.00 |  734.00 | 25.90 |
# | water             |    60.00 |  440.00 | 15.50 |
# | desem             |    10.00 |   73.40 |  2.59 |
#
# Final Dough:
#
# |                   |   baker% |    grams |    oz |
# |:------------------|---------:|---------:|------:|
# | whole-wheat-flour |   100.00 | 2,759.00 | 97.30 |
# | water             |    85.00 | 2,518.00 | 88.80 |
# | malt              |     0.80 |    27.60 |  0.97 |
# | salt              |     2.00 |    69.00 |  2.43 |
# | desem             |    34.00 | 1,104.00 | 38.90 |
