# %% [markdown]
# ## Whole Wheat Sourdough w/ Walnuts and Cranberries

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import RecipeCalculator, create_formula, format_and_display

# %%
calc = RecipeCalculator(
    num_loaves=12, 
    weight_grams=100,
    waste_factor=0.02
)
calc.print_batch_info()
# Out:
# 12 loaves at 95-105 grams
# total weight: 1,224.00 grams

# %%
pre_fermented_flour_ratio = 0.2
title='Whole Wheat Sourdough w/ Walnuts and Cranberries'

formula = create_formula({
    "whole-wheat-flour": 100,
    "water": 85,
    "malt": 0.8,
    "salt": 2,
    "walnuts": 20,
    "cranberries": 16
})

desem = create_formula({
    "whole-wheat-flour": 100,
    "water": 60,
    "seed": 10
})

steps='''
- Autolyse 15 min
- Bulk fermentation: 3 hr (fold every 15 min for first 90 min)
- shape
- Proof: 90 min'''

desem, final_dough = calc.calculate(formula, desem_df=desem, pre_fermented_flour_ratio=pre_fermented_flour_ratio)
format_and_display(formula=final_dough, desem=desem, calc=calc, title=title, steps=steps, reserved_seed_grams=75)
# Out:
# Whole Wheat Sourdough w/ Walnuts and Cranberries
#
#
# - Autolyse 15 min
# - Bulk fermentation: 3 hr (fold every 15 min for first 90 min)
# - shape
# - Proof: 90 min
#
# 12 loaves at 95-105 grams
# overall formula total = 226.5%
#
# Overall Formula:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | whole-wheat-flour |   100.00 |  540.00 | 19.10 |
# | cranberries       |    16.20 |   87.50 |  3.09 |
# | malt              |     0.81 |    4.38 |  0.15 |
# | salt              |     2.02 |   10.90 |  0.39 |
# | seed              |     1.90 |   10.30 |  0.36 |
# | walnuts           |    20.20 |  109.00 |  3.86 |
# | water             |    85.30 |  461.00 | 16.30 |
#
# Desem:
#
# |                   |   baker% |   grams |   oz |
# |:------------------|---------:|--------:|-----:|
# | whole-wheat-flour |   100.00 |  147.00 | 5.19 |
# | water             |    60.00 |   88.20 | 3.11 |
# | seed              |    10.00 |   14.70 | 0.52 |
#
# Final Dough:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | whole-wheat-flour |   100.00 |  438.00 | 15.40 |
# | water             |    85.00 |  399.00 | 14.10 |
# | malt              |     0.80 |    4.38 |  0.15 |
# | salt              |     2.00 |   10.90 |  0.39 |
# | walnuts           |    20.00 |  109.00 |  3.86 |
# | cranberries       |    16.00 |   87.50 |  3.09 |
# | desem             |    32.00 |  175.00 |  6.17 |
