# %% [markdown]
# ## Banh Mi Baguettes

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import RecipeCalculator, create_formula, format_and_display

# %%
formula = create_formula({
    "bread-flour": 70,
    "high-gluten-flour": 30,
    "water": 70,
    "sugar": 1.5,
    "salt": 2,
    "yeast": 1.4,
    "oil": 2
})

steps= '''
- bulk ferment 1 hr at 75F
- retard overnight
- shape as mini-baguettes
- proof 1 hr
- bake at 450, 20-25 min with steam
'''
title="Banh mi baguettes"

# %%
calc = RecipeCalculator(
    num_loaves=20, 
    weight_grams=150,
    waste_factor=0.02
)
calc.print_batch_info()
# Out:
# 20 loaves at 142-158 grams
# total weight: 3,060.00 grams

# %%
final_dough = calc.calculate_straight_dough(formula)
format_and_display(final_dough, calc, title=title, steps=steps)
# Out:
# Banh mi baguettes
#
#
# - bulk ferment 1 hr at 75F
# - retard overnight
# - shape as mini-baguettes
# - proof 1 hr
# - bake at 450, 20-25 min with steam
#
#
# 20 loaves at 142-158 grams
# overall formula total = 176.9%
#
# |                   |   baker% |    grams |    oz |
# |:------------------|---------:|---------:|------:|
# | bread-flour       |    70.00 | 1,211.00 | 42.70 |
# | high-gluten-flour |    30.00 |   519.00 | 18.30 |
# | water             |    70.00 | 1,211.00 | 42.70 |
# | sugar             |     1.50 |    25.90 |  0.92 |
# | salt              |     2.00 |    34.60 |  1.22 |
# | yeast             |     1.40 |    24.20 |  0.85 |
# | oil               |     2.00 |    34.60 |  1.22 |
