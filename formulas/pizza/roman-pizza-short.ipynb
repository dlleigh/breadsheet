# %% [markdown]
# ## Roman Pizza

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import RecipeCalculator, create_formula, format_and_display

# %%
calc = RecipeCalculator(
    num_loaves=2, 
    weight_grams=760,
    waste_factor=0.02
)
calc.print_batch_info()
# Out:
# 2 loaves at 722-798 grams
# total weight: 1,550.40 grams

# %%
pre_fermented_flour_ratio=.17
title='Roman Pizza'

formula = create_formula({
    "bread-flour": 100,
    "whole-wheat-flour": 16,
    "water": 83.5,
    "malt": 0.42,
    "salt": 1.83
})

levain = create_formula({
    "bread-flour": 100,
    "water": 100,
    "levain": 20
})


steps='''
- autolyse 20 min
- mix
- bulk ferment 1 hour, fold 2-3 times
- shape/pan 2-3 hours before baking
- bake 500 degrees
'''

levain, final_dough = calc.calculate(formula, levain_df=levain, pre_fermented_flour_ratio=pre_fermented_flour_ratio)
format_and_display(formula=final_dough, levain=levain, calc=calc, title=title, steps=steps, reserved_seed_grams=150)
# Out:
# Roman Pizza
#
#
# - autolyse 20 min
# - mix
# - bulk ferment 1 hour, fold 2-3 times
# - shape/pan 2-3 hours before baking
# - bake 500 degrees
#
#
# 2 loaves at 722-798 grams
# overall formula total = 176.7%
#
# Overall Formula:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | bread-flour       |    86.00 |  755.00 | 26.60 |
# | whole-wheat-flour |    14.00 |  123.00 |  4.34 |
# | levain            |     3.14 |   27.60 |  0.97 |
# | malt              |     0.37 |    3.23 |  0.11 |
# | salt              |     1.60 |   14.10 |  0.50 |
# | water             |    71.50 |  628.00 | 22.10 |
#
# levain:
#
# |             |   baker% |   grams |   oz |
# |:------------|---------:|--------:|-----:|
# | bread-flour |   100.00 |  206.00 | 7.26 |
# | water       |   100.00 |  206.00 | 7.26 |
# | levain      |    20.00 |   41.20 | 1.45 |
#
# Final Dough:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | bread-flour       |   100.00 |  617.00 | 21.80 |
# | whole-wheat-flour |    16.00 |  123.00 |  4.34 |
# | water             |    83.50 |  490.00 | 17.30 |
# | malt              |     0.42 |    3.23 |  0.11 |
# | salt              |     1.83 |   14.10 |  0.50 |
# | levain            |    34.00 |  303.00 | 10.70 |
