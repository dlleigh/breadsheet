# %% [markdown]
# ## 4-hour Pizza Dough
#
# From: _From The Wood-Fired Oven_ by Richard Miscovich (pg 141)

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import RecipeCalculator, create_formula, format_and_display

# %%
calc = RecipeCalculator(
    num_loaves=4, 
    weight_grams=283
)
calc.print_batch_info()
# Out:
# 4 loaves at 269-297 grams
# total weight: 1,132.00 grams

# %%
formula = create_formula({
    "ap-flour": 100, 
    "water": 65, 
    "yeast": 0.2,
    "salt": 1.8
})
steps= '''
- Autolyse: 20-30 min
- Divide
- Proof 4-5 hours
'''
title="Pizza"

# %%
final_dough = calc.calculate_straight_dough(formula)
format_and_display(final_dough, calc, title=title,steps=steps)
# Out:
# Pizza
#
#
# - Autolyse: 20-30 min
# - Divide
# - Proof 4-5 hours
#
#
# 4 loaves at 269-297 grams
# overall formula total = 167.0%
#
# |          |   baker% |   grams |    oz |
# |:---------|---------:|--------:|------:|
# | ap-flour |   100.00 |  678.00 | 23.90 |
# | water    |    65.00 |  441.00 | 15.50 |
# | yeast    |     0.20 |    1.36 |  0.05 |
# | salt     |     1.80 |   12.20 |  0.43 |
