# %% [markdown]
# ## Roman Pizza

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import RecipeCalculator, create_formula, format_and_display

# %%
calc = RecipeCalculator(
    num_loaves=2, 
    weight_grams=760,
    waste_factor=0.02
)
calc.print_batch_info()
# Out:
# 2 loaves at 722-798 grams
# total weight: 1,550.40 grams

# %%
pre_fermented_flour_ratio=.17
title='Roman Pizza'

formula = create_formula({
    "bread-flour": 100 * pre_fermented_flour_ratio,
    "high-gluten-flour": 67,
    "whole-wheat-flour": 16,
    "water": 83.5,
    "malt": 0.42,
    "salt": 1.83
})

levain = create_formula({
    "bread-flour": 100,
    "water": 100,
    "seed": 20
})


steps='''
- autolyse 20 min
- mix
- bulk ferment 1 hour, fold 2-3 times
- cold retard 42-78 hours
- shape/pan 2-3 hours before baking
- bake 500 degrees
'''

levain, final_dough = calc.calculate(formula, levain_df=levain, pre_fermented_flour_ratio=pre_fermented_flour_ratio)
format_and_display(formula=final_dough, levain=levain, calc=calc, title=title, steps=steps, reserved_seed_grams=150)
# Out:
# Roman Pizza
#
#
# - autolyse 20 min
# - mix
# - bulk ferment 1 hour, fold 2-3 times
# - cold retard 42-78 hours
# - shape/pan 2-3 hours before baking
# - bake 500 degrees
#
#
# 2 loaves at 722-798 grams
# overall formula total = 188.7%
#
# Overall Formula:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | bread-flour       |    15.70 |  129.00 |  4.55 |
# | high-gluten-flour |    68.10 |  559.00 | 19.70 |
# | whole-wheat-flour |    16.30 |  134.00 |  4.71 |
# | malt              |     0.43 |    3.51 |  0.12 |
# | salt              |     1.86 |   15.30 |  0.54 |
# | seed              |     3.14 |   25.80 |  0.91 |
# | water             |    83.20 |  684.00 | 24.10 |
#
# levain:
#
# |             |   baker% |   grams |   oz |
# |:------------|---------:|--------:|-----:|
# | bread-flour |   100.00 |  197.00 | 6.96 |
# | water       |   100.00 |  197.00 | 6.96 |
# | seed        |    20.00 |   39.40 | 1.39 |
#
# Final Dough:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | high-gluten-flour |    67.00 |  559.00 | 19.70 |
# | whole-wheat-flour |    16.00 |  134.00 |  4.71 |
# | water             |    83.50 |  555.00 | 19.60 |
# | malt              |     0.42 |    3.51 |  0.12 |
# | salt              |     1.83 |   15.30 |  0.54 |
# | levain            |    34.00 |  284.00 | 10.00 |
