# %% [markdown]
# ## Sourdough Semolina
# From _Bread_ by Jeffrey Hamelman

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import PrefermentCalculator, create_formula, format_and_display

# %%
calc = PrefermentCalculator(
    num_loaves=96, 
    weight_grams=80,
    waste_factor=0.02
)
calc.print_batch_info()
# Out:
# 96 loaves at 76-84 grams
# total weight: 7,833.60 grams

# %%
pre_fermented_flour_ratio = 0.15
title='Semolina Bread'

formula = create_formula({
    "bread-flour": 40,
    "durham-flour": 60,
    "water": 67,
    "malt": 1,
    #"sesame seeds": 5,
    "salt": 2
})

levain = create_formula({
    "bread-flour": 100,
    "water": 125,
    "seed": 20
})
steps='''
- Bulk fermentation: 120 min (fold once)
- Proof: 2 hrs
- Bake: 460F with steam
'''

levain, final_dough = calc.calculate(formula, levain_df=levain, pre_fermented_flour_ratio=pre_fermented_flour_ratio)
format_and_display(formula=final_dough, levain=levain, calc=calc, title=title, steps=steps)
# Out:
# Semolina Bread
#
#
# - Bulk fermentation: 120 min (fold once)
# - Proof: 2 hrs
# - Bake: 460F with steam
#
#
# 96 loaves at 76-84 grams
# overall formula total = 206.8%
#
# levain:
#
# |             |   baker% |   grams |    oz |
# |:------------|---------:|--------:|------:|
# | bread-flour |   100.00 |  691.00 | 24.40 |
# | water       |   125.00 |  864.00 | 30.50 |
# | seed        |    20.00 |  138.00 |  4.88 |
#
# Final Dough:
#
# |              |   baker% |    grams |    oz |
# |:-------------|---------:|---------:|------:|
# | bread-flour  |    40.00 | 1,152.00 | 40.60 |
# | durham-flour |    60.00 | 2,765.00 | 97.50 |
# | water        |    67.00 | 2,223.00 | 78.40 |
# | malt         |     1.00 |    46.10 |  1.63 |
# | salt         |     2.00 |    92.20 |  3.25 |
# | levain       |    36.80 | 1,693.00 | 59.70 |
