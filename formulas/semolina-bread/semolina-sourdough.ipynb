# %% [markdown]
# ## Sourdough Semolina
# From _Bread_ by Jeffrey Hamelman

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import PrefermentCalculator, create_formula, format_and_display

# %%
calc = PrefermentCalculator(
    num_loaves=75, 
    weight_grams=100,
    waste_factor=0.02
)
calc.print_batch_info()
# Out:
# 75 loaves at 95-105 grams
# total weight: 7,650.00 grams

# %%
pre_fermented_flour_ratio = 0.15
title='Semolina Bread'

formula = create_formula({
    "bread-flour": 40,
    "durham-flour": 60,
    "water": 67,
    "malt": 1,
    #"sesame seeds": 5,
    "salt": 2
})

levain = create_formula({
    "bread-flour": 100,
    "water": 125,
    "seed": 20
})
steps='''
- Bulk fermentation: 120 min (fold once)
- Proof: 2 hrs
- Bake: 460F with steam
'''

levain, final_dough = calc.calculate(formula, levain_df=levain, pre_fermented_flour_ratio=pre_fermented_flour_ratio)
format_and_display(formula=final_dough, levain=levain, calc=calc, title=title, steps=steps)
# Out:
# Semolina Bread
#
#
# - Bulk fermentation: 120 min (fold once)
# - Proof: 2 hrs
# - Bake: 460F with steam
#
#
# 75 loaves at 95-105 grams
# overall formula total = 206.8%
#
# levain:
#
# |             |   baker% |   grams |    oz |
# |:------------|---------:|--------:|------:|
# | bread-flour |   100.00 |  675.00 | 23.80 |
# | water       |   125.00 |  844.00 | 29.80 |
# | seed        |    20.00 |  135.00 |  4.76 |
#
# Final Dough:
#
# |              |   baker% |    grams |    oz |
# |:-------------|---------:|---------:|------:|
# | bread-flour  |    40.00 | 1,125.00 | 39.70 |
# | durham-flour |    60.00 | 2,700.00 | 95.20 |
# | water        |    67.00 | 2,171.00 | 76.60 |
# | malt         |     1.00 |    45.00 |  1.59 |
# | salt         |     2.00 |    90.00 |  3.17 |
# | levain       |    36.80 | 1,654.00 | 58.30 |
