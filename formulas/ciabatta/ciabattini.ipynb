# %% [markdown]
# ## Ciabattini

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import PrefermentCalculator, create_formula, format_and_display

# %%
calc = PrefermentCalculator(
    num_loaves=36, 
    weight_ounces=2.3
)
calc.print_batch_info()
# Out:
# 36 loaves at 62-68 grams
# total weight: 2,347.34 grams

# %%
pre_fermented_flour_ratio = .30
formula = create_formula({
    "flour": 100, 
    "water": 73, 
    "yeast": .44,
    "salt": 2,
})

poolish = create_formula({
    "flour": 100,
    "water": 100, 
    "yeast": 0.088
})

title='Ciabattini'
steps='''
- desired dough temp: 75F
- bulk fermentation: 3hrs, fold twice
- divide & shape
- final fermentation: 1.5 hrs
'''
poolish_weights, final_dough = calc.calculate_poolish_recipe(formula, poolish, 
                                                             pre_fermented_flour_ratio=pre_fermented_flour_ratio)

format_and_display(formula=final_dough, poolish=poolish_weights,
                   calc=calc, title=title, steps=steps)
# Out:
# Ciabattini
#
#
# - desired dough temp: 75F
# - bulk fermentation: 3hrs, fold twice
# - divide & shape
# - final fermentation: 1.5 hrs
#
#
# 36 loaves at 62-68 grams
# overall formula total = 175.4%
#
# Overall Formula:
#
# |       |   baker% |    grams |    oz |
# |:------|---------:|---------:|------:|
# | flour |   100.00 | 1,338.00 | 47.20 |
# | salt  |     2.00 |    26.80 |  0.94 |
# | water |    73.00 |   977.00 | 34.50 |
# | yeast |     0.44 |     5.89 |  0.21 |
#
# Poolish:
#
# |       |   baker% |   grams |    oz |
# |:------|---------:|--------:|------:|
# | flour |   100.00 |  401.00 | 14.20 |
# | water |   100.00 |  401.00 | 14.20 |
# | yeast |     0.09 |    0.35 |  0.01 |
#
# Final Dough:
#
# |         |   baker% |   grams |    oz |
# |:--------|---------:|--------:|------:|
# | flour   |   100.00 |  937.00 | 33.00 |
# | water   |    73.00 |  575.00 | 20.30 |
# | yeast   |     0.44 |    5.53 |  0.20 |
# | salt    |     2.00 |   26.80 |  0.94 |
# | poolish |    60.00 |  803.00 | 28.30 |
