# %% [markdown]
# ## Ciabattini

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import PrefermentCalculator, create_formula, format_and_display

# %%
calc = PrefermentCalculator(
    num_loaves=36, 
    weight_ounces=2.5
)
calc.print_batch_info()
# Out:
# 36 loaves at 71 grams
# total weight: 2,551.45 grams

# %%
pre_fermented_flour_ratio = .30
formula = create_formula({
    "flour": 100, 
    "water": 73, 
    "yeast": .44,
    "salt": 2,
})

poolish = create_formula({
    "flour": 100,
    "water": 100, 
    "yeast": 0.088
})

title='Ciabattini'
steps='''
- desired dough temp: 75F
- bulk fermentation: 3hrs, fold twice
- divide & shape
- final fermentation: 1.5 hrs
'''
poolish_weights, final_dough = calc.calculate_poolish_recipe(formula, poolish, 
                                                             pre_fermented_flour_ratio=pre_fermented_flour_ratio)

format_and_display(formula=final_dough, poolish=poolish_weights,
                   calc=calc, title=title, steps=steps)
# Out:
# Ciabattini
#
#
# - desired dough temp: 75F
# - bulk fermentation: 3hrs, fold twice
# - divide & shape
# - final fermentation: 1.5 hrs
#
#
# 36 loaves at 71 grams
# overall formula total = 235.5%
#
# Poolish:
#
# |       |   baker% |   grams |    oz |
# |:------|---------:|--------:|------:|
# | flour |   100    | 436     | 15.4  |
# | water |   100    | 436     | 15.4  |
# | yeast |     0.09 |   0.384 |  0.01 |
#
# Final Dough:
#
# |         |   baker% | grams   |    oz |
# |:--------|---------:|:--------|------:|
# | flour   |   100    | 1,018   | 35.9  |
# | water   |    73    | 625     | 22.1  |
# | yeast   |     0.44 | 6.02    |  0.21 |
# | salt    |     2    | 29.1    |  1.03 |
# | poolish |    60    | 873     | 30.8  |
#         baker%  grams    oz
# flour      100  1,018  35.9
# water     73.0    625  22.1
# yeast     0.44   6.02  0.21
# salt      2.00   29.1  1.03
# poolish   60.0    873  30.8
