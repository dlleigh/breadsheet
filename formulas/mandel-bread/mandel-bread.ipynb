# %% [markdown]
# ## Mandel Bread

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import RecipeCalculator, create_formula, format_and_display

# %%
calc = RecipeCalculator(
    num_loaves=2, 
    weight_grams=500
)
calc.print_batch_info()
# Out:
# 2 loaves at 475-525 grams
# total weight: 1,000.00 grams

# %%
title='Mandel Bread'

formula = create_formula({
    "oil": 38,
    "sugar": 23,
    "almond extract": 1.36,
    "egg": 34,
    "ap-flour": 100,
    "baking-powder": .9,
    "salt": .7,
    "almonds": 32
})

steps='''
- Beat together oil, sugar and extract.  
- Beat eggs and add to mixture.  
- Mix together flour, baking powder and salt and add to mixture.  
- Add nuts.  
- Shape into loaves.  
- Bake in 350 degree oven for 30 minutes or until done.
'''

final_dough = calc.calculate_straight_dough(formula)
format_and_display(final_dough, calc, title=title, steps=steps, show_volume=True)
# Out:
# Mandel Bread
#
#
# - Beat together oil, sugar and extract.
# - Beat eggs and add to mixture.
# - Mix together flour, baking powder and salt and add to mixture.
# - Add nuts.
# - Shape into loaves.
# - Bake in 350 degree oven for 30 minutes or until done.
#
#
# 2 loaves at 475-525 grams
# overall formula total = 230.0%
#
# |                |   baker% |   grams |    oz |   volume |
# |:---------------|---------:|--------:|------:|---------:|
# | oil            |    38.00 |  165.00 |  5.83 |  3/4 cup |
# | sugar          |    23.00 |  100.00 |  3.53 |  1/2 cup |
# | almond extract |     1.36 |    5.91 |  0.21 |    1 tsp |
# | egg            |    34.00 |  148.00 |  5.22 |   3 eggs |
# | ap-flour       |   100.00 |  435.00 | 15.30 |          |
# | baking-powder  |     0.90 |    3.91 |  0.14 |    1 tsp |
# | salt           |     0.70 |    3.04 |  0.11 |  1/2 tsp |
# | almonds        |    32.00 |  139.00 |  4.91 |    1 cup |
