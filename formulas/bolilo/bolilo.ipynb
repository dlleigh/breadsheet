# %% [markdown]
# ## Bolilo

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import RecipeCalculator, create_formula, format_and_display

# %%
formula = create_formula({
    "flour": 100,
    "water": 50,
    "egg": 10,
    "butter": 10,
    "sugar": 5,
    "salt": 2,
    "yeast": 1.4,
})
steps= '''
- bulk ferment 2 hr at 75F
- shape as mini-baguettes
- proof 1 hr 
- bake at 420, 20-25 min with steam
'''
title="Bolilo"

# %%
calc = RecipeCalculator(
    num_loaves=36, 
    weight_grams=125
)
calc.print_batch_info()
# Out:
# 36 loaves at 125 grams
# total weight: 4,500.00 grams

# %%
final_dough = calc.calculate_straight_dough(formula)
format_and_display(final_dough, calc, title=title, steps=steps)
# Out:
# Bolilo
#
#
# - bulk ferment 2 hr at 75F
# - shape as mini-baguettes
# - proof 1 hr
# - bake at 420, 20-25 min with steam
#
#
# 36 loaves at 125 grams
# overall formula total = 178.4%
#
# |        |   baker% | grams   |    oz |
# |:-------|---------:|:--------|------:|
# | flour  |    100   | 2,522   | 89    |
# | water  |     50   | 1,261   | 44.5  |
# | egg    |     10   | 252     |  8.9  |
# | butter |     10   | 252     |  8.9  |
# | sugar  |      5   | 126     |  4.45 |
# | salt   |      2   | 50.4    |  1.78 |
# | yeast  |      1.4 | 35.3    |  1.25 |
#        baker%  grams    oz
# flour     100  2,522  89.0
# water    50.0  1,261  44.5
# egg      10.0    252  8.90
# butter   10.0    252  8.90
# sugar    5.00    126  4.45
# salt     2.00   50.4  1.78
# yeast    1.40   35.3  1.25
