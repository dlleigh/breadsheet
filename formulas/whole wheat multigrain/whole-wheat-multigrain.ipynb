# %%
import sys
sys.path.append('../..')
from breadsheet_utils import RecipeCalculator, create_formula, format_and_display

# %%
calc = RecipeCalculator(
    num_loaves=3, 
    weight_grams=623,
    #waste_factor=0.01
)
calc.print_batch_info()
# Out:
# 3 loaves at 592-654 grams
# total weight: 1,869.00 grams

# %%
pre_fermented_flour_ratio = 0.35
title='Whole Wheat Multigrain Bread'

formula = create_formula({
    "ww-flour": 50,
    "bread-flour": 50,
    "cracked-wheat (soaker)": 5,
    "coarse-cornmeal (soaker)": 5,
    "millet (soaker)": 5,
    "oats (soaker)": 5,
    "water": 53,
    "soaker water (boiling)": 25,
    "salt": 2.4,
    "yeast": .43,
    "honey": 5
})

pate_fermentee = create_formula({
    "bread-flour": 100,
    "water": 65,
    "salt": 2,
    "yeast": 0.066
})

steps='''
- prepare pate fermentee at least 12-16 hours ahead
- prepare soaker at least 4 hours ahead
- add pate fermentee after other ingredients are mixed
- bulk ferment: 2 hours, fold once
- divide and shape
- proof: 60-90 min
- bake at 450F with steam
'''

pate_fermentee, final_dough = calc.calculate(formula, pate_fermentee_df=pate_fermentee, 
                                             pre_fermented_flour_ratio=pre_fermented_flour_ratio)
format_and_display(formula=final_dough, pate_fermentee=pate_fermentee, calc=calc, title=title, steps=steps)
# Out:
# Whole Wheat Multigrain Bread
#
#
#
#
# 3 loaves at 592-654 grams
# overall formula total = 386.4%
#
# Soaker:
#
# |                          |   baker% |   grams |   oz |
# |:-------------------------|---------:|--------:|-----:|
# | cracked-wheat (soaker)   |     5.00 |   45.40 | 1.60 |
# | coarse-cornmeal (soaker) |     5.00 |   45.40 | 1.60 |
# | millet (soaker)          |     5.00 |   45.40 | 1.60 |
# | oats (soaker)            |     5.00 |   45.40 | 1.60 |
# | soaker water             |    25.00 |  227.00 | 8.01 |
#
#
# Pâte Fermentée:
#
# |             |   baker% |   grams |    oz |
# |:------------|---------:|--------:|------:|
# | bread-flour |   100.00 |  318.00 | 11.20 |
# | water       |    65.00 |  207.00 |  7.29 |
# | salt        |     2.00 |    6.36 |  0.22 |
# | yeast       |     0.07 |    0.21 |  0.01 |
#
# Final Dough:
#
# |                |   baker% |   grams |    oz |
# |:---------------|---------:|--------:|------:|
# | ww-flour       |    50.00 |  454.00 | 16.00 |
# | bread-flour    |    50.00 |  136.00 |  4.80 |
# | water          |    53.00 |  275.00 |  9.69 |
# | salt           |     2.40 |   15.40 |  0.54 |
# | yeast          |     0.43 |    3.69 |  0.13 |
# | honey          |     5.00 |   45.40 |  1.60 |
# | pâte fermentée |    58.50 |  531.00 | 18.70 |
