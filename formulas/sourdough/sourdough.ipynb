# %% [markdown]
# ## Sourdough

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import PrefermentCalculator, create_formula, format_and_display

# %%
calc = PrefermentCalculator(
    num_loaves=4, 
    weight_pounds=1,
    weight_ounces=12
)
calc.print_batch_info()
# Out:
# 4 loaves at 754-833 grams
# total weight: 3,175.14 grams

# %%
pre_fermented_flour_ratio = 0.20
title='Sourdough'

formula = create_formula({
    "bread-flour": 90,
    "whole-wheat-flour": 10,
    "levain": 40,
    "water": 66.11,
    "malt": 1,
    "salt": 2.36
})

steps='''
- Autolyse 25 min
- Bulk fermentation: 150 min (fold every 50 min)
- Proof: 2 hrs'''

final_dough = calc.calculate_straight_dough(formula)
format_and_display(final_dough, calc, title=title, steps=steps)
# Out:
# Sourdough
#
#
# - Autolyse 25 min
# - Bulk fermentation: 150 min (fold every 50 min)
# - Proof: 2 hrs
#
# 4 loaves at 754-833 grams
# overall formula total = 209.5%
#
# |                   |   baker% | grams   |    oz |
# |:------------------|---------:|:--------|------:|
# | bread-flour       |    90    | 1,364   | 48.1  |
# | whole-wheat-flour |    10    | 152     |  5.35 |
# | levain            |    40    | 606     | 21.4  |
# | water             |    66.1  | 1,002   | 35.3  |
# | malt              |     1    | 15.2    |  0.53 |
# | salt              |     2.36 | 35.8    |  1.26 |
#                   baker%  grams    oz
# bread-flour         90.0  1,364  48.1
# whole-wheat-flour   10.0    152  5.35
# levain              40.0    606  21.4
# water               66.1  1,002  35.3
# malt                1.00   15.2  0.53
# salt                2.36   35.8  1.26
