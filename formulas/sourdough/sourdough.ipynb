# %% [markdown]
# ## Sourdough

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import PrefermentCalculator, create_formula, format_and_display

# %%
calc = PrefermentCalculator(
    num_loaves=8, 
    weight_pounds=1,
    weight_ounces=12
)
calc.print_batch_info()
# Out:
# 8 loaves at 754-833 grams
# total weight: 6,350.29 grams

# %%
pre_fermented_flour_ratio = 0.20
title='Sourdough'

formula = create_formula({
    "bread-flour": 90,
    "whole-wheat-flour": 10,
    "levain": 40,
    "water": 66.11,
    "malt": 1,
    "salt": 2.36
})

steps='''
- Autolyse 25 min
- Bulk fermentation: 150 min (fold every 50 min)
- Proof: 2 hrs'''

final_dough = calc.calculate_straight_dough(formula)
format_and_display(final_dough, calc, title=title, steps=steps)
# Out:
# Sourdough
#
#
# - Autolyse 25 min
# - Bulk fermentation: 150 min (fold every 50 min)
# - Proof: 2 hrs
#
# 8 loaves at 754-833 grams
# overall formula total = 209.5%
#
# |                   |   baker% |    grams |    oz |
# |:------------------|---------:|---------:|------:|
# | bread-flour       |    90.00 | 2,728.00 | 96.20 |
# | whole-wheat-flour |    10.00 |   303.00 | 10.70 |
# | levain            |    40.00 | 1,213.00 | 42.80 |
# | water             |    66.10 | 2,004.00 | 70.70 |
# | malt              |     1.00 |    30.30 |  1.07 |
# | salt              |     2.36 |    71.50 |  2.52 |
