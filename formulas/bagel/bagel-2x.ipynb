# %% [markdown]
# ## Bagel
#
# From _The Bread Baker's Apprentice_ by Peter Reinhart

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import PrefermentCalculator, create_formula, format_and_display

# %%
calc = PrefermentCalculator(
    num_loaves=24, 
    weight_grams=133)
calc.print_batch_info()
# Out:
# 24 loaves at 133 grams
# total weight: 3,192.00 grams

# %%
dough = create_formula({
    "high-gluten-flour": 48.6, 
    "yeast": 0.16,
    "salt": 2,
    "malt": 0.94
})

sponge = create_formula({
    "high-gluten-flour": 51.4,
    "water": 57.1, 
    "yeast": 0.31
})

steps = '''
- mix sponge, rest 2 hr
- mix dough
- divide & preshape: 20 min
- shape
- proof: 20 min (until they float)
- retard: 8-36 hours
- boil: 1 min per side
- bake: 5 min per side
'''

title='Bagles'

# %%
sponge_weights, final_dough = calc.calculate_sponge_recipe(sponge_df=sponge,
                                                           dough_df=dough)

format_and_display(formula=final_dough, sponge=sponge_weights,
                   calc=calc, title=title, steps=steps)
# Out:
# Bagles
#
#
# - mix sponge, rest 2 hr
# - mix dough
# - divide & preshape: 20 min
# - shape
# - proof: 20 min (until they float)
# - retard: 8-36 hours
# - boil: 1 min per side
# - bake: 5 min per side
#
#
# 24 loaves at 133 grams
# overall formula total = 51.7%
#
# sponge:
#
# |                   |   baker% | grams   |    oz |
# |:------------------|---------:|:--------|------:|
# | high-gluten-flour |    51.4  | 1,022   | 36.1  |
# | water             |    57.1  | 1,136   | 40.1  |
# | yeast             |     0.31 | 6.16    |  0.22 |
#
# Final Dough:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | high-gluten-flour |    48.6  |  966    | 34.1  |
# | yeast             |     0.16 |    3.18 |  0.11 |
# | salt              |     2    |   39.8  |  1.4  |
# | malt              |     0.94 |   18.7  |  0.66 |
#                   baker% grams    oz
# high-gluten-flour   48.6   966  34.1
# yeast               0.16  3.18  0.11
# salt                2.00  39.8  1.40
# malt                0.94  18.7  0.66
