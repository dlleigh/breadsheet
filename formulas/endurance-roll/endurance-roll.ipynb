# %% [markdown]
# ## Endurance Roll

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import PrefermentCalculator, create_formula, format_and_display

# %%
calc = PrefermentCalculator(
    num_loaves=24, 
    weight_grams=50,
    waste_factor=0.02
    )
calc.print_batch_info()
# Out:
# 24 loaves at 48-52 grams
# total weight: 1,224.00 grams

# %%
pre_fermented_flour_ratio = .55
hydration = 62

dough = create_formula({
    "high-gluten flour": 70,
    "WW flour": 30, 
    "water": hydration,
    "salt": 2.5,
    "instant yeast": .81,
    "malt": 0.94,
    "molasses": 8,
    "olive oil": 4,
    "almonds": 16,
    "dates": 30,
    "chocolate": 9
})

sponge = create_formula({
    "high-gluten flour": 100,
    "water": hydration / pre_fermented_flour_ratio, 
    "instant yeast": 0.56
})

steps = '''
- mix sponge, rest 2 hr
- mix dough, adding nuts & dried fruit at end of mix
- divide & shape (with chocolate)
- retard: 8-36 hours
- boil: 30s per side
- bake: 450 degrees, 20 min
'''

title='Endurance Roll'

# %%
sponge_weights, final_dough = calc.calculate_sponge_recipe(dough, sponge, pre_fermented_flour_ratio)

format_and_display(formula=final_dough, sponge=sponge_weights,
                   calc=calc, title=title, steps=steps)
# Out:
# Endurance Roll
#
#
# - mix sponge, rest 2 hr
# - mix dough, adding nuts & dried fruit at end of mix
# - divide & shape (with chocolate)
# - retard: 8-36 hours
# - boil: 30s per side
# - bake: 450 degrees, 20 min
#
#
# 24 loaves at 48-52 grams
# overall formula total = 233.2%
#
# Overall Formula:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | WW flour          |    30.00 |  157.00 |  5.55 |
# | high-gluten flour |    70.00 |  367.00 | 13.00 |
# | almonds           |    16.00 |   84.00 |  2.96 |
# | chocolate         |     9.00 |   47.20 |  1.67 |
# | dates             |    30.00 |  157.00 |  5.55 |
# | instant yeast     |     0.81 |    4.25 |  0.15 |
# | malt              |     0.94 |    4.93 |  0.17 |
# | molasses          |     8.00 |   42.00 |  1.48 |
# | olive oil         |     4.00 |   21.00 |  0.74 |
# | salt              |     2.50 |   13.10 |  0.46 |
# | water             |    62.00 |  325.00 | 11.50 |
#
# sponge:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | high-gluten flour |   100.00 |  289.00 | 10.20 |
# | water             |   113.00 |  325.00 | 11.50 |
# | instant yeast     |     0.56 |    1.62 |  0.06 |
#
# Final Dough:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | high-gluten flour |    70.00 |   78.70 |  2.78 |
# | WW flour          |    30.00 |  157.00 |  5.55 |
# | salt              |     2.50 |   13.10 |  0.46 |
# | instant yeast     |     0.81 |    2.63 |  0.09 |
# | malt              |     0.94 |    4.93 |  0.17 |
# | molasses          |     8.00 |   42.00 |  1.48 |
# | olive oil         |     4.00 |   21.00 |  0.74 |
# | almonds           |    16.00 |   84.00 |  2.96 |
# | dates             |    30.00 |  157.00 |  5.55 |
# | chocolate         |     9.00 |   47.20 |  1.67 |
# | sponge            |   117.00 |  616.00 | 21.70 |
