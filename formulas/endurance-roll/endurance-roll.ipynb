# %% [markdown]
# ## Endurance Roll

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import PrefermentCalculator, create_formula, format_and_display

# %%
calc = PrefermentCalculator(
    num_loaves=12, 
    weight_grams=100)
calc.print_batch_info()
# Out:
# 12 loaves at 100 grams
# total weight: 1,200.00 grams

# %%
dough = create_formula({
    "high-gluten-flour": 15,
    "WW Flour": 30, 
    "yeast": 0.5,
    "salt": 2.5,
    "malt": 0.94,
    "molasses": 8,
    "olive oil": 4,
    "mix-ins (dates/apricots/almonds)": 30
})

sponge = create_formula({
    "high-gluten-flour": 55,
    "water": 65, 
    "yeast": 0.31
})

steps = '''
- mix sponge, rest 2 hr
- mix dough
- divide & preshape: 20 min
- shape
- proof: 20 min (until they float)
- retard: 8-36 hours
- boil: 30s per side
- bake: 450 degrees, 20 min
'''

title='Endurance Roll'

# %%
sponge_weights, final_dough = calc.calculate_sponge_recipe(sponge_df=sponge,
                                                           dough_df=dough)

format_and_display(formula=final_dough, sponge=sponge_weights,
                   calc=calc, title=title, steps=steps)
# Out:
# Endurance Roll
#
#
# - mix sponge, rest 2 hr
# - mix dough
# - divide & preshape: 20 min
# - shape
# - proof: 20 min (until they float)
# - retard: 8-36 hours
# - boil: 30s per side
# - bake: 450 degrees, 20 min
#
#
# 12 loaves at 100 grams
# overall formula total = 211.2%
#
# sponge:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | high-gluten-flour |    55    |  312    | 11    |
# | water             |    65    |  369    | 13    |
# | yeast             |     0.31 |    1.76 |  0.06 |
#
# Final Dough:
#
# |                                  |   baker% |   grams |   oz |
# |:---------------------------------|---------:|--------:|-----:|
# | high-gluten-flour                |    15    |   85.2  | 3.01 |
# | WW Flour                         |    30    |  170    | 6.01 |
# | yeast                            |     0.5  |    2.84 | 0.1  |
# | salt                             |     2.5  |   14.2  | 0.5  |
# | malt                             |     0.94 |    5.34 | 0.19 |
# | molasses                         |     8    |   45.4  | 1.6  |
# | olive oil                        |     4    |   22.7  | 0.8  |
# | mix-ins (dates/apricots/almonds) |    30    |  170    | 6.01 |
#                                  baker% grams    oz
# high-gluten-flour                  15.0  85.2  3.01
# WW Flour                           30.0   170  6.01
# yeast                              0.50  2.84  0.10
# salt                               2.50  14.2  0.50
# malt                               0.94  5.34  0.19
# molasses                           8.00  45.4  1.60
# olive oil                          4.00  22.7  0.80
# mix-ins (dates/apricots/almonds)   30.0   170  6.01
