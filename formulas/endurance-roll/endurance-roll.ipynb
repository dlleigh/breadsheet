# %% [markdown]
# ## Endurance Roll

# %%
import sys
sys.path.append('../..')
from breadsheet_utils import PrefermentCalculator, create_formula, format_and_display

# %%
calc = PrefermentCalculator(
    num_loaves=12, 
    weight_grams=100,
    waste_factor=0.02
    )
calc.print_batch_info()
# Out:
# 12 loaves at 95-105 grams
# total weight: 1,224.00 grams

# %%
pre_fermented_flour_ratio = .55

dough = create_formula({
    "high-gluten flour": 70,
    "WW flour": 30, 
    "water": 62,
    "salt": 2.5,
    "instant yeast": .81,
    "malt": 0.94,
    "molasses": 8,
    "olive oil": 4,
    "almonds": 16,
    "dates": 14,
    "chocolate": 9
})

sponge = create_formula({
    "high-gluten flour": 100,
    "water": 62 / pre_fermented_flour_ratio, 
    "instant yeast": 0.56
})

steps = '''
- mix sponge, rest 2 hr
- mix dough, adding nuts & dried fruit at end of mix
- divide & shape (with chocolate)
- retard: 8-36 hours
- boil: 30s per side
- bake: 45 degrees, 20 min
'''

title='Endurance Roll'

# %%
sponge_weights, final_dough = calc.calculate_sponge_recipe(dough, sponge, pre_fermented_flour_ratio)

format_and_display(formula=final_dough, sponge=sponge_weights,
                   calc=calc, title=title, steps=steps)
# Out:
# Endurance Roll
#
#
# - mix sponge, rest 2 hr
# - mix dough, adding nuts & dried fruit at end of mix
# - divide & shape (with chocolate)
# - retard: 8-36 hours
# - boil: 30s per side
# - bake: 45 degrees, 20 min
#
#
# 12 loaves at 95-105 grams
# overall formula total = 547.8%
#
# sponge:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | high-gluten flour |   100.00 |  310.00 | 10.90 |
# | water             |   113.00 |  349.00 | 12.30 |
# | instant yeast     |     0.56 |    1.74 |  0.06 |
#
# Final Dough:
#
# |                   |   baker% |   grams |    oz |
# |:------------------|---------:|--------:|------:|
# | high-gluten flour |    70.00 |   84.50 |  2.98 |
# | WW flour          |    30.00 |  169.00 |  5.96 |
# | salt              |     2.50 |   14.10 |  0.50 |
# | instant yeast     |     0.81 |    2.83 |  0.10 |
# | malt              |     0.94 |    5.30 |  0.19 |
# | molasses          |     8.00 |   45.10 |  1.59 |
# | olive oil         |     4.00 |   22.50 |  0.79 |
# | almonds           |    16.00 |   90.10 |  3.18 |
# | dates             |    14.00 |   78.90 |  2.78 |
# | chocolate         |     9.00 |   50.70 |  1.79 |
# | sponge            |   117.00 |  661.00 | 23.30 |
